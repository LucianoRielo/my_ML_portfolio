# %% [markdown]
# ## **Training the model with MNIST dataset**

# %% [markdown]
# #### Import Libraries

# %%
import tensorflow as tf
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D
import numpy as np
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### Load MNIST dataset

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

print(f'-------------------------\n')
print(f'Matrix X_train contains {X_train.shape[0]} images (resolution = {X_train.shape[1]} X {X_train.shape[2]})\n')
print(f'For all images X_train there are {y_train.shape[0]} labels, that goes from {min(y_train)} to {max(y_train)}\n')
print(f'-------------------------\n')
print(f'Matrix X_test contains {X_test.shape[0]} ({X_test.shape[1]} X {X_test.shape[2]} resolution)\n')
print(f'For all images X_test there are {y_test.shape[0]} labels, that goes from {min(y_test)} to {max(y_test)}\n')
print(f'-------------------------\n')
print(f'Each model has {X_train[0].shape[0]} x {X_train[0].shape[1]} = {X_train[0].shape[0]*X_train[0].shape[1]} features')
print(f'-------------------------\n')
print(f'Values from X_train and X_test goes from {np.min(X_train[0])} to {np.max(X_train[0])}\n')
print(f'-------------------------\n')

X_train = X_train / np.max(X_train[0])  # now values from 0 to 1
X_test = X_test / np.max(X_test[0])
# Out:
# -------------------------
#
# Matrix X_train contains 60000 images (resolution = 28 X 28)
#
# For all images X_train there are 60000 labels, that goes from 0 to 9
#
# -------------------------
#
# Matrix X_test contains 10000 (28 X 28 resolution)
#
# For all images X_test there are 10000 labels, that goes from 0 to 9
#
# -------------------------
#
# Each model has 28 x 28 = 784 features
# -------------------------
#
# Values from X_train and X_test goes from 0 to 255
#
# -------------------------

# %% [markdown]
# #### Create Models

# %%
model_1 = Sequential(
    [
    Flatten(input_shape=(28,28)),
    Dense(25,activation='relu'),
    Dense(15,activation='relu'),
    Dense(10,activation='softmax'),
    ],
    name = 'model_1'
)

model_2 = Sequential(
    [
    Flatten(input_shape=(28,28)),
    Dense(128,activation='relu'),
    Dense(10,activation='softmax'),
    ],
    name = 'model_2'
)

model_3 = Sequential(
    [
        Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1)),  # 28,28,1 (gray scale images 28x28)
        Conv2D(32, kernel_size=(3,3)),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.2),
        Dense(10,activation='softmax'),
    ],
    name = 'model_3'
)

model_4 = Sequential(
    [
        Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1)),  # 28,28,1 (gray scale images 28x28)
        Conv2D(32, kernel_size=(3,3)),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(64, kernel_size=(3,3)),
        Conv2D(64, kernel_size=(3,3)),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.2),
        Dense(10,activation='softmax'),
    ],
    name = 'model_4'
)

model_5 = Sequential(
    [
        Conv2D(16, kernel_size=(3,3), input_shape=(28,28,1)),  # 28,28,1 (gray scale images 28x28)
        Conv2D(16, kernel_size=(3,3)),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(32, kernel_size=(3,3)),
        Conv2D(32, kernel_size=(3,3)),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.2),
        Dense(10,activation='softmax'),
    ],
    name = 'model_5'
)

model_6 = Sequential(
    [
        Conv2D(16, kernel_size=(3,3), input_shape=(28,28,1)),  # 28,28,1 (gray scale images 28x28)
        Conv2D(16, kernel_size=(3,3)),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(64, kernel_size=(3,3)),
        Conv2D(64, kernel_size=(3,3)),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.2),
        Dense(10,activation='softmax'),
    ],
    name = 'model_6'
)

models = [model_1, model_2, model_3, model_4, model_5, model_6]

# %%
accuracy_scores = []
histories = []

for model in models:
    model.compile(
        loss = 'sparse_categorical_crossentropy',
        # loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False),
        optimizer = 'Adam',
        # optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
        metrics=['accuracy'],
    )

    print(f'Training {model.name}...')

    history = model.fit(
        X_train,
        y_train,
        epochs = 15,
    )
    histories.append(history)

    print(f'Done!\n')

    y_prob = model.predict(X_test)
    y_hat = y_prob.argmax(axis=1).astype(np.uint8)

    accuracy_scores.append(accuracy_score(y_test,y_hat))
# Out:
# Training model_1...
# Epoch 1/15
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3935 - accuracy: 0.8874
# Epoch 2/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2150 - accuracy: 0.9364
# Epoch 3/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1761 - accuracy: 0.9480
# Epoch 4/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1521 - accuracy: 0.9549
# Epoch 5/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1343 - accuracy: 0.9594
# Epoch 6/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1215 - accuracy: 0.9631
# Epoch 7/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1114 - accuracy: 0.9661
# Epoch 8/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1023 - accuracy: 0.9696
# Epoch 9/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0946 - accuracy: 0.9710
# Epoch 10/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0880 - accuracy: 0.9733
# Epoch 11/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0847 - accuracy: 0.9743
# Epoch 12/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0773 - accuracy: 0.9762
# Epoch 13/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0734 - accuracy: 0.9773
# Epoch 14/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0688 - accuracy: 0.9787
# Epoch 15/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0661 - accuracy: 0.9793
# Done!
#
# 313/313 [==============================] - 0s 1ms/step
# Training model_2...
# Epoch 1/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2595 - accuracy: 0.9257
# Epoch 2/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1127 - accuracy: 0.9668
# Epoch 3/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0782 - accuracy: 0.9766
# Epoch 4/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0575 - accuracy: 0.9823
# Epoch 5/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0456 - accuracy: 0.9858
# Epoch 6/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0359 - accuracy: 0.9886
# Epoch 7/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0282 - accuracy: 0.9911
# Epoch 8/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0231 - accuracy: 0.9931
# Epoch 9/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0192 - accuracy: 0.9938
# Epoch 10/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0150 - accuracy: 0.9953
# Epoch 11/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0141 - accuracy: 0.9955
# Epoch 12/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0109 - accuracy: 0.9965
# Epoch 13/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0097 - accuracy: 0.9971
# Epoch 14/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0096 - accuracy: 0.9971
# Epoch 15/15
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0092 - accuracy: 0.9969
# Done!
#
# 313/313 [==============================] - 1s 2ms/step
# Training model_3...
# Epoch 1/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1737 - accuracy: 0.9476
# Epoch 2/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0688 - accuracy: 0.9788
# Epoch 3/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0534 - accuracy: 0.9835
# Epoch 4/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0402 - accuracy: 0.9870
# Epoch 5/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0334 - accuracy: 0.9885
# Epoch 6/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0316 - accuracy: 0.9895
# Epoch 7/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0252 - accuracy: 0.9915
# Epoch 8/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0238 - accuracy: 0.9925
# Epoch 9/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0230 - accuracy: 0.9925
# Epoch 10/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0199 - accuracy: 0.9934
# Epoch 11/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0194 - accuracy: 0.9939
# Epoch 12/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0202 - accuracy: 0.9936
# Epoch 13/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0179 - accuracy: 0.9939
# Epoch 14/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0175 - accuracy: 0.9944
# Epoch 15/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0162 - accuracy: 0.9949
# Done!
#
# 313/313 [==============================] - 1s 2ms/step
# Training model_4...
# Epoch 1/15
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.1453 - accuracy: 0.9556
# Epoch 2/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0678 - accuracy: 0.9797
# Epoch 3/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0562 - accuracy: 0.9829
# Epoch 4/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0483 - accuracy: 0.9855
# Epoch 5/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0418 - accuracy: 0.9873
# Epoch 6/15
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0418 - accuracy: 0.9872
# Epoch 7/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0349 - accuracy: 0.9891
# Epoch 8/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0337 - accuracy: 0.9895
# Epoch 9/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0335 - accuracy: 0.9896
# Epoch 10/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0330 - accuracy: 0.9902
# Epoch 11/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0282 - accuracy: 0.9917
# Epoch 12/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0310 - accuracy: 0.9910
# Epoch 13/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0300 - accuracy: 0.9911
# Epoch 14/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0257 - accuracy: 0.9923
# Epoch 15/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0278 - accuracy: 0.9919
# Done!
#
# 313/313 [==============================] - 1s 2ms/step
# Training model_5...
# Epoch 1/15
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.1593 - accuracy: 0.9511
# Epoch 2/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0645 - accuracy: 0.9802
# Epoch 3/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0509 - accuracy: 0.9845
# Epoch 4/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0427 - accuracy: 0.9867
# Epoch 5/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0366 - accuracy: 0.9885
# Epoch 6/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0340 - accuracy: 0.9894
# Epoch 7/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0312 - accuracy: 0.9903
# Epoch 8/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0295 - accuracy: 0.9904
# Epoch 9/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0268 - accuracy: 0.9913
# Epoch 10/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0275 - accuracy: 0.9912
# Epoch 11/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0234 - accuracy: 0.9924
# Epoch 12/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0216 - accuracy: 0.9929
# Epoch 13/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0241 - accuracy: 0.9924
# Epoch 14/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0186 - accuracy: 0.9941
# Epoch 15/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0205 - accuracy: 0.9937
# Done!
#
# 313/313 [==============================] - 1s 3ms/step
# Training model_6...
# Epoch 1/15
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.1474 - accuracy: 0.9543
# Epoch 2/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0630 - accuracy: 0.9811
# Epoch 3/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0518 - accuracy: 0.9842
# Epoch 4/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0458 - accuracy: 0.9858
# Epoch 5/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0387 - accuracy: 0.9881
# Epoch 6/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0339 - accuracy: 0.9894
# Epoch 7/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0328 - accuracy: 0.9897
# Epoch 8/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0298 - accuracy: 0.9910
# Epoch 9/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0285 - accuracy: 0.9915
# Epoch 10/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0256 - accuracy: 0.9919
# Epoch 11/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0253 - accuracy: 0.9923
# Epoch 12/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0231 - accuracy: 0.9924
# Epoch 13/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0221 - accuracy: 0.9933
# Epoch 14/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0228 - accuracy: 0.9929
# Epoch 15/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0236 - accuracy: 0.9933
# Done!
#
# 313/313 [==============================] - 1s 2ms/step

# %%
print(f'RESULTS:')
for i in range(len(models)):
    print(f'model_{i+1}:\n'+
          f'accuracy = {accuracy_scores[i]:.4f}\n')
# Out:
# RESULTS:
# model_1:
# accuracy = 0.9617
#
# model_2:
# accuracy = 0.9794
#
# model_3:
# accuracy = 0.9856
#
# model_4:
# accuracy = 0.9861
#
# model_5:
# accuracy = 0.9872
#
# model_6:
# accuracy = 0.9915

# %% [markdown]
# #### model_6 have better accuracy than the others

# %%
model_6.save('CNN.hdf5')
